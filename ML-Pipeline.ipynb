# %%
from ml_modules.pipeline_data import *
from ml_modules.pipeline_ml import *
from ml_modules.metric_reporting import *


df = pd.read_csv("data_incoming\Data_Incoming.csv")

df = preprocess_raw_data ( df )
df = generate_features ( df )
# df = gen_PCA_features ( df )

df , X , Y = export_processed_data ( df )
# Out:
# c:\Users\sraja\Miniconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\sraja\Miniconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\sraja\Miniconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# catboost 1.1.1
# skopt 0.9.0
# sklearn 1.1.3

# %% [markdown]
# ## Final classifier model run
# ### with-out full Hyperparameter Tuning pipeline

# %%
X_train, Y_train, Y_train_pred, X_test, Y_test, Y_test_pred, model  = run_ml_pipeline( X,Y, tune_FLAG = False )
# Out:
# X size :  (5496, 24)
# Y size :  (5496,)
# X_train size :  (4946, 24)
# Y_train size :  (4946,)
# X_test  size :  (550, 24)
# Y_test  size :  (550,)
# X , Y , Y_Pred Data Exported as CSV

# %%
get_classifier_analytics( Y_train ,  Y_train_pred , Y_test , Y_test_pred , X_train , X_test , model )
# Out:
# Confusion matrix Format
# [ [ tn , fp ]     all 0z
#   [ fn , tp ] ]   all 1z
#
#
# Confusion Matrix for Train :
#
# [[4447    0]
#  [ 499    0]]
#
# [[0.89911039 0.        ]
#  [0.10088961 0.        ]]
#
#
# Confusion Matrix for Test :
#
# [[477   0]
#  [ 73   0]]
#
# [[0.86727273 0.        ]
#  [0.13272727 0.        ]]
#
#
#
# ###########################################################################
#
# F1 Score for Train :  0.0
# F1 Score for Test  :  0.0
# F1 Score for Train Dummy :  0.11507936507936509
# F1 Score for Test  Dummy :  0.0746268656716418
#
#
# Training Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95      4946
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.90      4946
#    macro avg       0.50      0.45      0.47      4946
# weighted avg       1.00      0.90      0.95      4946
#
#
# Testing  Classification Report
# ...

# %% [markdown]
# ## Run with full HyperParameter Tuning

# %%
X_train, Y_train, Y_train_pred, X_test, Y_test, Y_test_pred, model  = run_ml_pipeline( X,Y, tune_FLAG = True )
# Out:
# X size :  (5496, 24)
# Y size :  (5496,)
# X_train size :  (4946, 24)
# Y_train size :  (4946,)
# X_test  size :  (550, 24)
# Y_test  size :  (550,)
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# ...

# %%
get_classifier_analytics( Y_train ,  Y_train_pred , Y_test , Y_test_pred , X_train , X_test , model )
# Out:
# Confusion matrix Format
# [ [ tn , fp ]     all 0z
#   [ fn , tp ] ]   all 1z
#
#
# Confusion Matrix for Train :
#
# [[4362   63]
#  [ 510   11]]
#
# [[0.88192479 0.01273757]
#  [0.10311363 0.00222402]]
#
#
# Confusion Matrix for Test :
#
# [[489  10]
#  [ 51   0]]
#
# [[0.88909091 0.01818182]
#  [0.09272727 0.        ]]
#
#
#
# ###########################################################################
#
# F1 Score for Train :  0.03697478991596639
# F1 Score for Test  :  0.0
# F1 Score for Train Dummy :  0.09876543209876543
# F1 Score for Test  Dummy :  0.13793103448275862
#
#
# Training Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      4872
#            1       0.02      0.15      0.04        74
#
#     accuracy                           0.88      4946
#    macro avg       0.50      0.52      0.49      4946
# weighted avg       0.97      0.88      0.92      4946
#
#
# Testing  Classification Report
# ...
